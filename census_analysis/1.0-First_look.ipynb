# %%
# %%javascript
# $('#menubar').toggle();

# %% [markdown]
# Data from [data.census.org](https://data.census.gov/cedsci/table?q=ACSST5Y2018.S2001%20New%20York%20city,%20New%20York&g=0100000US.860000&y=2018&tid=ACSST5Y2018.S2001&moe=false&hidePreview=true).
#
# Seems like we must use the 5 year estimates from 2018 (2019 doesn't have 5 year estimates).
# The 1 year estimates don't provide ZIP code granularity.
#
# See also [When to Use 1-year, 3-year, or 5-year Estimates](https://www.census.gov/programs-surveys/acs/guidance/estimates.html)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
import seaborn as sns
sns.set()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
FILE_PATH = "data/ACSST5Y2018.S2001_data_with_overlays_2020-11-20T230734.csv"

# %%
income = pd.read_csv(FILE_PATH, skiprows=[1])
income.head(5)
# Out:
#            GEO_ID         NAME  S2001_C01_001E  S2001_C01_001M  \
# 0  8600000US00601  ZCTA5 00601          4165.0           407.0
# 1  8600000US00602  ZCTA5 00602         12288.0           603.0
# 2  8600000US00603  ZCTA5 00603         13838.0           697.0
# 3  8600000US00606  ZCTA5 00606          1489.0           175.0
# 4  8600000US00610  ZCTA5 00610          9100.0           619.0
#
#    S2001_C02_001E  S2001_C02_001M  S2001_C03_001E  S2001_C03_001M  \
# 0          4165.0           407.0          2347.0           260.0
# 1         12288.0           603.0          7017.0           409.0
# 2         13838.0           697.0          7840.0           495.0
# 3          1489.0           175.0          1003.0           149.0
# 4          9100.0           619.0          5116.0           381.0
#
#    S2001_C04_001E  S2001_C04_001M  S2001_C05_001E  S2001_C05_001M  \
# 0          2347.0           260.0          1818.0           261.0
# 1          7017.0           409.0          5271.0           442.0
# 2          7840.0           495.0          5998.0           425.0
# 3          1003.0           149.0           486.0           126.0
# 4          5116.0           381.0          3984.0           399.0
#
#    S2001_C06_001E  S2001_C06_001M S2001_C01_002E S2001_C01_002M  \
# 0          1818.0           261.0          14448           1245
# 1          5271.0           442.0          13322           1139
# 2          5998.0           425.0          15980            677
# 3           486.0           126.0          10554           2480
# 4          3984.0           399.0          15298            717
#
#   S2001_C02_002E S2001_C02_002M S2001_C03_002E S2001_C03_002M S2001_C04_002E  \
# 0            (X)            (X)          14331           1329            (X)
# 1            (X)            (X)          13222           1292            (X)
# 2            (X)            (X)          16205            851            (X)
# 3            (X)            (X)           9913           3259            (X)
# 4            (X)            (X)          14931           1031            (X)
#
#   S2001_C04_002M S2001_C05_002E S2001_C05_002M S2001_C06_002E  ...  \
# 0            (X)          14641           2242            (X)  ...
# 1            (X)          13487           1639            (X)  ...
# 2            (X)          15656           1237            (X)  ...
# 3            (X)          11231           4545            (X)  ...
# 4            (X)          15629           1026            (X)  ...
#
#   S2001_C06_018M  S2001_C01_019E  S2001_C01_019M  S2001_C02_019E  \
# 0            (X)           19840            2299             (X)
# 1            (X)           19317            1409             (X)
# 2            (X)           23089            2843             (X)
# 3            (X)           23194            9551             (X)
# 4            (X)           25833            3599             (X)
#
#    S2001_C02_019M  S2001_C03_019E  S2001_C03_019M  S2001_C04_019E  \
# 0             (X)           17241           16214             (X)
# 1             (X)           26048            1923             (X)
# 2             (X)           30125            8970             (X)
# 3             (X)           17188           16394             (X)
# 4             (X)           28591            4740             (X)
#
#    S2001_C04_019M  S2001_C05_019E  S2001_C05_019M  S2001_C06_019E  \
# 0             (X)           19950            1990             (X)
# 1             (X)           18176            1296             (X)
# 2             (X)           19411            2836             (X)
# 3             (X)           25321            8802             (X)
# 4             (X)           21994            4142             (X)
#
#    S2001_C06_019M  S2001_C01_020E  S2001_C01_020M S2001_C02_020E  \
# 0             (X)           27333           18271            (X)
# 1             (X)           29073            5815            (X)
# 2             (X)           40570            6690            (X)
# 3             (X)               -              **            (X)
# 4             (X)           35234            3263            (X)
#
#   S2001_C02_020M  S2001_C03_020E  S2001_C03_020M S2001_C04_020E  \
# 0            (X)           37667            5276            (X)
# 1            (X)           43676           17019            (X)
# 2            (X)           49946            9084            (X)
# 3            (X)               -              **            (X)
# 4            (X)           38152            2679            (X)
#
#   S2001_C04_020M  S2001_C05_020E  S2001_C05_020M S2001_C06_020E S2001_C06_020M
# 0            (X)           19697           10134            (X)            (X)
# 1            (X)           26864            2872            (X)            (X)
# 2            (X)           32171            6709            (X)            (X)
# 3            (X)               -              **            (X)            (X)
# 4            (X)           33143            7189            (X)            (X)
#
# [5 rows x 242 columns]

# %% [markdown]
# - How to deal with ZCTA?
# > In most instances the ZCTA code is the same as the ZIP Code for an area.
# from [here](https://www.census.gov/programs-surveys/geography/guidance/geo-areas/zctas.html)

# %%
# Use slice 6 because there's a space after 'ZCTA5'
income["processed_zip"] = income["NAME"].str.slice(6)

# %%
sample_complaints = pd.read_csv("data/sample_complaints.csv")
sample_complaints.head(2)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    25356119  04/13/2013 03:55:00 PM  04/13/2013 03:55:00 PM    DEP
# 1    25356123  04/13/2013 03:36:00 PM  04/13/2013 04:00:00 PM    DEP
#
#                               Agency Name Complaint Type  \
# 0  Department of Environmental Protection          Sewer
# 1  Department of Environmental Protection   Water System
#
#                          Descriptor Location Type  Incident Zip  \
# 0  Sewer Backup (Use Comments) (SA)           NaN       11429.0
# 1             Hydrant Leaking (WC1)           NaN       10460.0
#
#        Incident Address          Street Name   Cross Street 1 Cross Street 2  \
# 0  215-27 HOLLIS AVENUE        HOLLIS AVENUE           215 ST         216 ST
# 1   EAST TREMONT AVENUE  EAST TREMONT AVENUE  PROSPECT AVENUE   MAPES AVENUE
#
#   Intersection Street 1 Intersection Street 2 Address Type            City  \
# 0                   NaN                   NaN      ADDRESS  Queens Village
# 1                   NaN                   NaN    BLOCKFACE           BRONX
#
#   Landmark Facility Type  Status Due Date  \
# 0      NaN           NaN  Closed      NaN
# 1      NaN           NaN  Closed      NaN
#
#                               Resolution Description  \
# 0  The Department of Environmental Protection has...
# 1  The Department of Environmental Protection det...
#
#   Resolution Action Updated Date Community Board           BBL Borough  \
# 0         04/13/2013 03:55:00 PM       13 QUEENS  4.111010e+09  QUEENS
# 1         04/13/2013 04:00:00 PM        06 BRONX           NaN   BRONX
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                   1055561.0                    198095.0
# 1                   1015108.0                    246825.0
#
#   Open Data Channel Type Park Facility Name Park Borough  Vehicle Type  \
# 0                  PHONE        Unspecified       QUEENS           NaN
# 1                  PHONE        Unspecified        BRONX           NaN
#
#    Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0                   NaN                   NaN                 NaN
# 1                   NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.710114
# 1                      NaN       NaN                    NaN  40.844100
#
#    Longitude                   Location
# 0 -73.742781  (40.7101144, -73.7427809)
# 1 -73.888469  (40.8440997, -73.8884686)

# %%
print("% ofinvalid zips", 100*sample_complaints["Incident Zip"].isna().mean())
sample_complaints.dropna(subset=["Incident Zip"], inplace=True)
# Out:
# % ofinvalid zips 0.40040040040040037

# %%
sample_complaints["processed_zip"] = sample_complaints["Incident Zip"].astype(int).astype(str)

# %%
pd.merge(sample_complaints, income, 
         on="processed_zip", validate="m:1")[["processed_zip", "S2001_C01_001E"]]
# Out:
#     processed_zip  S2001_C01_001E
# 0           11429         15130.0
# 1           11429         15130.0
# 2           11429         15130.0
# 3           10460         25474.0
# 4           10460         25474.0
# ..            ...             ...
# 989         11364         19615.0
# 990         11419         26256.0
# 991         11419         26256.0
# 992         11358         18953.0
# 993         11358         18953.0
#
# [994 rows x 2 columns]

# %%
"""
"S2001_C03_013E","Estimate!!Male!!Population 16 years and over with earnings!!FULL-TIME, YEAR-ROUND WORKERS WITH EARNINGS!!Median earnings (dollars) for full-time, year-round workers with earnings"
"""
# Out:
# '\n"S2001_C03_013E","Estimate!!Male!!Population 16 years and over with earnings!!FULL-TIME, YEAR-ROUND WORKERS WITH EARNINGS!!Median earnings (dollars) for full-time, year-round workers with earnings"\n'
