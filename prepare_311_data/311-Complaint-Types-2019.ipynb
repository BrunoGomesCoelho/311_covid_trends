# %% [markdown]
# # Exploring 311 complaint types in 2019
#
# ## Read data

# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('311-2019.csv', low_memory=False)

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    41316662  01/01/2019 12:00:00 AM  01/02/2019 12:00:00 AM  DOHMH
# 1    41316968  01/01/2019 12:00:00 AM  01/15/2019 04:28:53 PM  DOHMH
# 2    41318587  01/01/2019 12:00:00 AM  01/01/2019 12:00:00 AM  DOHMH
# 3    41309122  01/01/2019 12:00:00 AM  01/10/2019 12:00:00 AM  DOHMH
# 4    41310910  01/01/2019 12:00:00 AM  01/01/2019 12:00:00 AM  DOHMH
#
#                                Agency Name Complaint Type      Descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent    Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent    Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent    Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Mouse Sighting
# 4  Department of Health and Mental Hygiene         Rodent    Rat Sighting
#
#              Location Type Incident Zip          Incident Address  ...  \
# 0       Parking Lot/Garage        11374  62-54 JUNCTION BOULEVARD  ...
# 1  3+ Family Apt. Building        11219   5906 NEW UTRECHT AVENUE  ...
# 2  3+ Family Apt. Building        10456      1220 GRAND CONCOURSE  ...
# 3  3+ Family Apt. Building        11373           90-34 52 AVENUE  ...
# 4  3+ Family Apt. Building        10459       899 EAST 169 STREET  ...
#
#   Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.731209
# 1                      NaN       NaN                    NaN  40.628319
# 2                      NaN       NaN                    NaN  40.834950
# 3                      NaN       NaN                    NaN  40.738877
# 4                      NaN       NaN                    NaN  40.828471
#
#    Longitude                   Location
# 0 -73.863580  (40.7312085, -73.8635797)
# 1 -73.996624  (40.6283191, -73.9966244)
# 2 -73.917266  (40.8349502, -73.9172664)
# 3 -73.872492  (40.7388766, -73.8724916)
# 4 -73.895453   (40.8284714, -73.895453)
#
# [5 rows x 41 columns]

# %% [markdown]
# ## List the most common complaints

# %%
type_counts = Counter(df['Complaint Type'].value_counts().to_dict())

# %%
type_counts.most_common(150)
# Out:
# [('Noise - Residential', 232164),
#  ('HEAT/HOT WATER', 211466),
#  ('Illegal Parking', 197891),
#  ('Blocked Driveway', 137303),
#  ('Request Large Bulky Item Collection', 99538),
#  ('Noise - Street/Sidewalk', 97821),
#  ('Street Condition', 88124),
#  ('Street Light Condition', 67936),
#  ('Water System', 63349),
#  ('UNSANITARY CONDITION', 57714),
#  ('Noise', 56216),
#  ('General Construction/Plumbing', 48150),
#  ('Noise - Vehicle', 43006),
#  ('Sidewalk Condition', 42537),
#  ('Missed Collection (All Materials)', 40510),
#  ('Noise - Commercial', 40432),
#  ('Traffic Signal Condition', 39866),
#  ('PLUMBING', 35892),
#  ('Derelict Vehicles', 35711),
#  ('PAINT/PLASTER', 34238),
#  ('Sewer', 31729),
#  ('Dirty Conditions', 31698),
#  ('Rodent', 31597),
#  ('Damaged Tree', 26256),
#  ('WATER LEAK', 24600),
#  ('DOOR/WINDOW', 24527),
#  ('Abandoned Vehicle', 24070),
#  ('Building/Use', 23154),
#  ('Graffiti', 22638),
#  ('Sanitation Condition', 21833),
#  ('Homeless Person Assistance', 21026),
#  ('Electronics Waste Appointment', 18808),
#  ('GENERAL', 18121),
#  ('Derelict Vehicle', 17777),
#  ('For Hire Vehicle Complaint', 17760),
#  ('New Tree Request', 17444),
#  ('ELECTRIC', 17130),
#  ('Elevator', 16336),
#  ('Maintenance or Facility', 15209),
#  ('Broken Parking Meter', 14566),
#  ('Overgrown Tree/Branches', 14455),
#  ('Consumer Complaint', 14334),
#  ('FLOORING/STAIRS', 14084),
#  ('Taxi Complaint', 11566),
#  ('Food Establishment', 10508),
#  ('APPLIANCE', 10177),
#  ('Non-Emergency Police Matter', 10072),
#  ('Dead/Dying Tree', 10001),
#  ('Root/Sewer/Sidewalk Condition', 9990),
#  ('Lead', 8709),
#  ('Construction Safety Enforcement', 8214),
#  ('Air Quality', 8009),
#  ('Curb Condition', 7236),
#  ('Lost Property', 7169),
#  ('SAFETY', 7116),
#  ('Homeless Encampment', 7043),
#  ('Street Sign - Damaged', 6219),
#  ('DOF Property - Reduction Issue', 5737),
#  ('Special Projects Inspection Team (SPIT)', 5363),
#  ('Unsanitary Condition', 5359),
#  ('Street Sign - Missing', 5184),
#  ('Plumbing', 5050),
#  ('Vending', 4847),
#  ('Traffic', 4655),
#  ('Benefit Card Replacement', 4555),
#  ('Emergency Response Team (ERT)', 4291),
#  ('Other Enforcement', 4206),
#  ('Water Conservation', 4204),
#  ('Animal-Abuse', 4185),
#  ('Noise - Park', 4014),
#  ('Indoor Air Quality', 3775),
#  ('Animal Abuse', 3721),
#  ('Borough Office', 3604),
#  ('Illegal Tree Damage', 3506),
#  ('DOF Property - Request Copy', 3471),
#  ('Street Sign - Dangling', 3362),
#  ('Highway Condition', 3327),
#  ('Noise - Helicopter', 3282),
#  ('Violation of Park Rules', 2974),
#  ('Hazardous Materials', 2899),
#  ('Food Poisoning', 2773),
#  ('DOF Property - Payment Issue', 2609),
#  ('Drug Activity', 2574),
#  ('SCRIE', 2516),
#  ('DOF Property - Update Account', 2490),
#  ('Smoking', 2471),
#  ('Derelict Bicycle', 2463),
#  ('Electrical', 2439),
#  ('Boilers', 2389),
#  ('Housing - Low Income Senior', 2336),
#  ('Animal in a Park', 2276),
#  ('Mobile Food Vendor', 2088),
#  ('Water Quality', 2051),
#  ('Standing Water', 2041),
#  ('Asbestos', 2009),
#  ('Panhandling', 1920),
#  ('Snow', 1862),
#  ('Unsanitary Animal Pvt Property', 1833),
#  ('DOF Parking - Payment Issue', 1704),
#  ('Drinking', 1675),
#  ('School Maintenance', 1529),
#  ('Taxi Report', 1467),
#  ('Litter Basket / Request', 1338),
#  ('Building Marshals office', 1301),
#  ('Indoor Sewage', 1288),
#  ('HPD Literature Request', 1226),
#  ('BEST/Site Safety', 1206),
#  ('Industrial Waste', 1139),
#  ('General', 1093),
#  ('Non-Residential Heat', 1080),
#  ('ELEVATOR', 1043),
#  ('Bus Stop Shelter Complaint', 928),
#  ('Illegal Fireworks', 914),
#  ('DOF Property - Owner Issue', 901),
#  ('Vacant Lot', 870),
#  ('Investigations and Discipline (IAD)', 850),
#  ('Noise - House of Worship', 755),
#  ('Sustainability Enforcement', 749),
#  ('Housing Options', 710),
#  ('Bike/Roller/Skate Chronic', 678),
#  ('DPR Internal', 676),
#  ('DRIE', 657),
#  ('Unleashed Dog', 641),
#  ('For Hire Vehicle Report', 623),
#  ('Unsanitary Pigeon Condition', 616),
#  ('Urinating in Public', 609),
#  ('OUTSIDE BUILDING', 577),
#  ('DCA / DOH New License Application Request', 563),
#  ('Question', 559),
#  ('Recycling Enforcement', 525),
#  ('Day Care', 517),
#  ('Overflowing Litter Baskets', 461),
#  ('Mosquitoes', 447),
#  ('Ferry Inquiry', 427),
#  ('Safety', 416),
#  ('Mold', 414),
#  ('DOF Property - Property Value', 390),
#  ('Missed Collection', 340),
#  ('Public Payphone Complaint', 335),
#  ('Sweeping/Missed', 305),
#  ('Bridge Condition', 300),
#  ('DOF Parking - Request Copy', 291),
#  ('DEP Street Condition', 289),
#  ('Executive Inspections', 288),
#  ('Facades', 279),
#  ('DOF Property - RPIE Issue', 273),
#  ('Special Operations', 253),
#  ('DOF Parking - Request Status', 229),
#  ('Illegal Animal Kept as Pet', 227),
#  ('Poison Ivy', 220)]

# %%
def get_discriptor_counts(descriptor):
    return df[df['Complaint Type'] == descriptor]['Descriptor'].value_counts()

# %% [markdown]
# ## Explore noise complaints

# %%
noise_complaint_types = [
    complaint
    for complaint in df['Complaint Type'].unique()
    if 'noise' in complaint.lower()
]

noise_complaint_types
# Out:
# ['Noise - Residential',
#  'Noise - Commercial',
#  'Noise - Street/Sidewalk',
#  'Noise',
#  'Noise - Vehicle',
#  'Noise - Park',
#  'Noise - Helicopter',
#  'Noise - House of Worship',
#  'Collection Truck Noise']

# %%
for complaint in noise_complaint_types:
    print(f'Complaint Type: {complaint}')
    print('Descriptors:')
    print(get_discriptor_counts(complaint))
    print('\n')
# Out:
# Complaint Type: Noise - Residential
# Descriptors:
# Loud Music/Party    147533
# Banging/Pounding     65027
# Loud Talking         15155
# Loud Television       4449
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Noise - Commercial
# Descriptors:
# Loud Music/Party    30155
# Banging/Pounding     5022
# Loud Talking         3380
# Car/Truck Music      1090
# Car/Truck Horn        723
# Loud Television        62
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Noise - Street/Sidewalk
# Descriptors:
# Loud Music/Party    77751
# Loud Talking        20070
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Noise
# Descriptors:
# Noise: Construction Before/After Hours (NM1)             25992
# Noise, Barking Dog (NR5)                                  7209
# Noise: Construction Equipment (NC1)                       6882
# Noise: air condition/ventilation equipment (NV1)          4573
# Noise: Alarms (NR3)                                       4124
# Noise: Jack Hammering (NC2)                               3038
# Noise: Private Carting Noise (NQ1)                        1597
# Noise, Ice Cream Truck (NR4)                              1500
# Noise: lawn care equipment (NCL)                           565
# Noise: Boat(Engine,Music,Etc) (NR10)                       363
# Noise, Other Animals (NR6)                                 201
# Noise: Manufacturing Noise (NK1)                           141
# Noise: Other Noise Sources (Use Comments) (NZZ)             17
# Noise: Loud Music/Nighttime(Mark Date And Time) (NP1)        9
# Noise: Loud Music/Daytime (Mark Date And Time) (NN1)         5
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Noise - Vehicle
# Descriptors:
# Car/Truck Music    21650
# Car/Truck Horn     13107
# Engine Idling       8249
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Noise - Park
# Descriptors:
# Loud Music/Party    3405
# Loud Talking         609
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Noise - Helicopter
# Descriptors:
# Other             3048
# NYPD               163
# News Gathering      71
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Noise - House of Worship
# Descriptors:
# Loud Music/Party    425
# Loud Talking        259
# Banging/Pounding     71
# Name: Descriptor, dtype: int64
#
#
# Complaint Type: Collection Truck Noise
# Descriptors:
# 21 Collection Truck Noise    131
# Name: Descriptor, dtype: int64

# %% [markdown]
# ## Explore other complaints that may be impacted by COVID

# %%
get_discriptor_counts('Consumer Complaint')
# Out:
# Retail Store                   2466
# Overcharge                      707
# Exchange/Refund/Return          701
# Non-Delivery Goods/Services     638
# Tow Truck Company               562
#                                ...
# High Pressure Sales               1
# Extra Parts                       1
# Public Event Seating              1
# Toy Gun Sale                      1
# No or Defective Headphones        1
# Name: Descriptor, Length: 120, dtype: int64

# %%
get_discriptor_counts('Taxi Complaint')
# Out:
# Driver Complaint - Passenger        5933
# Driver Complaint - Non Passenger    2905
# Driver Complaint                    2170
# Vehicle Complaint                    330
# Insurance Information Requested      227
# Driver Report - Non Passenger          1
# Name: Descriptor, dtype: int64

# %%
get_discriptor_counts('Food Establishment')
# Out:
# Rodents/Insects/Garbage          2672
# Food Contaminated                1086
# Food Spoiled                     1024
# Bare Hands in Contact w/ Food     725
# Letter Grading                    719
# Food Contains Foreign Object      567
# Kitchen/Food Prep Area            440
# Pet/Animal                        432
# Food Temperature                  327
# Food Worker Hygiene               323
# Food Protection                   317
# No Permit or License              280
# Toilet Facility                   268
# Food Preparation Location         199
# Odor                              169
# Permit/License/Certificate        153
# Facility Construction             129
# Dishwashing/Utensils              119
# Food Worker Activity               89
# Handwashing                        86
# Toxic Chemical/Material            57
# Sewage                             57
# Ventilation                        52
# Allergy Information                50
# Plumbing                           39
# Food Worker Illness                34
# Pesticide                          32
# Water                              28
# Sign                               19
# Sodium Warning                      8
# Lighting                            6
# Milk Not Pasteurized                2
# Name: Descriptor, dtype: int64

# %%
get_discriptor_counts('Street Condition')
# Out:
# Pothole                           51478
# Cave-in                           10080
# Defective Hardware                 5704
# Rough, Pitted or Cracked Roads     5480
# Failed Street Repair               4463
# Blocked - Construction             4068
# Plate Condition - Noisy            1700
# Line/Marking - Faded               1534
# Wear & Tear                        1283
# Plate Condition - Shifted           939
# Line/Marking - After Repaving       416
# Dumpster - Construction Waste       199
# Plate Condition - Open              193
# Crash Cushion Defect                178
# Maintenance Cover                   109
# Guard Rail - Street                  86
# Plate Condition - Anti-Skid          80
# Hummock                              79
# Street Cave-In                       24
# Unsafe Worksite                      10
# Depression Maintenance                5
# General Bad Condition                 5
# Crack Sealing                         3
# Defacement                            3
# Strip Paving                          2
# Suspected Street Cut                  2
# Concrete Walls                        1
# Name: Descriptor, dtype: int64

# %%
get_discriptor_counts('Traffic')
# Out:
# Congestion/Gridlock            2358
# Truck Route Violation          1216
# Drag Racing                     391
# Chronic Speeding                356
# Chronic Stoplight Violation     334
# Name: Descriptor, dtype: int64
